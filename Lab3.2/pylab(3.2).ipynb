# %%
my_list = []
while True:
    print("\nList operations")
    print("1. insert an element")
    print("2. delete an element")
    print("3. find an element")
    print("4. display list")
    print("5. exit")
    try:
        choice = int(input("enter your choice 1-5: "))
    except ValueError:
        print("invalid input")
        continue
    match choice:
        case 1:
            element = input("enter element to be inserted: ")
            my_list.append(element)
            print(f"{element} inserted into list")
        case 2:
            element = input("enter element to be deleted: ")
            if element in my_list:
                my_list.remove(element)
                print(f"{element} deleted in list")
            else:
                print(f"{element} not found in the list, cannot delete.")
        case 3:
            element = input("enter element to be found: ")
            if element in my_list:
                index = my_list.index(element)
                print(f"{element} found at index {index}")
            else:
                print(f"{element} not found in the list.")
        case 4:
            print("current list: ", my_list)
        case 5:
            print("exiting program")
            break
        case _:
            print("Invalid choice. Please enter a number between 1 and 5.")
# Out:
# List operations
# 1. insert an element
# 2. delete an element
# 3. find an element
# 4. display list
# 5. exit
# enter your choice 1-5:  1
# enter element to be inserted:  10
# 10 inserted into list
#
# List operations
# 1. insert an element
# 2. delete an element
# 3. find an element
# 4. display list
# 5. exit
# enter your choice 1-5:  1
# enter element to be inserted:  20
# 20 inserted into list
#
# List operations
# 1. insert an element
# 2. delete an element
# 3. find an element
# 4. display list
# 5. exit
# enter your choice 1-5:  1
# enter element to be inserted:  30
# 30 inserted into list
#
# List operations
# 1. insert an element
# 2. delete an element
# 3. find an element
# 4. display list
# 5. exit
# enter your choice 1-5:  2
# enter element to be deleted:  20
# 20 deleted in list
#
# List operations
# 1. insert an element
# 2. delete an element
# 3. find an element
# 4. display list
# 5. exit
# enter your choice 1-5:  3
# enter element to be found:  30
# ...
