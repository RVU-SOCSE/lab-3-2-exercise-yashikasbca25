# %%
set={1,2,3,4,5}
print(set)
# Out:
# {1, 2, 3, 4, 5}

# %%
set={1,2,3,"apple","banana"}
print(set)
# Out:
# {1, 2, 3, 'apple', 'banana'}

# %%
set={1,2,3,"apple","banana"}
print(len(set))
# Out:
# 5

# %%
set={1,2,3,"apple","banana"}
set.add("orange")
print(set)
# Out:
# {1, 2, 3, 'apple', 'banana', 'orange'}

# %%
set={1,2,3,"apple","banana","orange"}
set.remove("orange")
print(set)
# Out:
# {1, 2, 3, 'apple', 'banana'}

# %%
set={1,2,3,"apple","banana","orange"}
x=set.copy()
print(x)
# Out:
# {1, 2, 3, 'apple', 'banana', 'orange'}

# %%
set1={1,2,3,"apple","banana","orange"}
set2={4,5,6,"grapes","cherry","banana"}
z=set1.difference(set2)
print(z)
# Out:
# {1, 2, 3, 'apple', 'orange'}

# %%
set1={1,2,3,"apple","banana","orange"}
set2={4,5,6,"grapes","cherry","banana"}
set1.difference_update(set2)
print(set1)
# Out:
# {1, 2, 3, 'apple', 'orange'}

# %%
set1={1,2,3,"apple","banana","orange"}
set1.discard("banana")
print(set1)
# Out:
# {1, 2, 3, 'apple', 'orange'}

# %%
set1={1,2,3,"apple","banana","orange"}
set2={4,5,6,"grapes","cherry","banana"}
z=set1.intersection(set2)
print(z)
# Out:
# {'banana'}

# %%
set1={1,2,3,"apple","banana","orange"}
set2={4,5,6,"grapes","cherry","banana"}
z=set1.intersection_update(set2)
print(set1)
# Out:
# {'banana'}

# %%
set1={1,2,3,"apple","banana","orange"}
set2={4,5,6,"grapes","cherry","banana"}
z=set1.isdisjoint(set2)
print(z)
# Out:
# False

# %%
set1={1,2,3,"apple","banana","orange"}
set2={4,5,6,"grapes","cherry","banana"}
z=set1.issubset(set2)
print(z)
# Out:
# False

# %%
set1={1,2,3,"apple","banana","orange"}
set2={4,5,6,"grapes","cherry","banana"}
z=set1.issuperset(set2)
print(z)
# Out:
# False

# %%
set1={1,2,3,"apple","banana","orange"}
set1.pop()
print(set1)
# Out:
# {2, 3, 'apple', 'banana', 'orange'}

# %%
set1={1,2,3,"apple","banana","orange"}
set2={4,5,6,"grapes","cherry","banana"}
z=set1.symmetric_difference(set2)
print(z)
# Out:
# {1, 2, 3, 4, 5, 6, 'apple', 'cherry', 'orange', 'grapes'}

# %%
set1={1,2,3,"apple","banana","orange"}
set2={4,5,6,"grapes","cherry","banana"}
z=set1.symmetric_difference_update(set2)
print(set1)
# Out:
# {1, 2, 3, 'apple', 4, 5, 6, 'cherry', 'orange', 'grapes'}

# %%
set1={1,2,3,"apple","banana","orange"}
set2={4,5,6,"grapes","cherry","banana"}
z=set1.union(set2)
print(z)
# Out:
# {1, 2, 3, 'apple', 4, 5, 6, 'cherry', 'orange', 'banana', 'grapes'}

# %%
set1={1,2,3,"apple","banana","orange"}
set2={4,5,6,"grapes","cherry","banana"}
z=set1.update(set2)
print(set1)
# Out:
# {1, 2, 3, 'apple', 4, 5, 6, 'cherry', 'orange', 'banana', 'grapes'}
